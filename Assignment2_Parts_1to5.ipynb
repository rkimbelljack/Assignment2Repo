# %% [markdown]
# # Lab Assignment 2 – Rachel Kimbell-Jack
# ### Student code: 210016757
# ---
#
# GitHub repository: https://github.com/rkimbelljack/Assignment2Repo

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %%
from arcgis.gis import GIS
gis = GIS("home")

# %% [markdown]
# ## Part 1: Python Basics

# %% [markdown]
# ### Task 1
# Create an If...Else statement that will test whether a number is divisible by three. "YOUR VALUE is divisible by 3" should be printed if the value is divisible by three. "YOUR VALUE is not divisible by three" should be printed if it is not divisible by three. Test the statement on a numeric variable. Upper case text in the print statement should be replaced with the tested number

# %%
def isDivisibleBy3(num):
    if(num % 3 == 0):
        print(str(num) + " is divisable by 3.")
    else:
        print(str(num) + " is not divisable by 3.")

# %%
#test cases 
isDivisibleBy3(10) #not div by 3
isDivisibleBy3(21) #div by 3
# Out:
# 10 is not divisable by 3.
# 21 is divisable by 3.

# %% [markdown]
# ### Task 2
# Create an If...Else statement that will test whether a type of fruit, represented as a text string, is in a list of acceptable fruits (apple, orange, pear, kiwi, or strawberry). If the fruit is on the list, the following should be printed: "YOUR FRUIT is acceptable." If not, then the following should be printed: "YOUR FRUIT is not acceptable." Upper case text in the print statement should be replaced with the tested fruit.

# %%
def acceptableFruits(fruit):
    fruits = ["apple", "orange", "pear", "kiwi", "strawberry"]
    for i in range(len(fruits)):
        if fruit == fruits[i]:
            print(fruit + " is acceptable")
            break
        elif i<len(fruits)-1:
            i+=1
        else:
            print(fruit + " is not acceptable")

# %%
#test cases 
acceptableFruits("banana") #not in list
acceptableFruits("apple") #in list
# Out:
# banana is not acceptable
# apple is acceptable

# %% [markdown]
# ### Task 3
# Create a function to calculate the distance between two coordinates using the haversine
# formula. Write the following formula where the input parameters are a pair of coordinates as two
# lists.

# %%
from math import *
def calc_dist(lati, long):
    #define variables 
    lati1 = radians(A[0])
    long1 = radians(B[0])
    lati2 = radians(A[1])
    long2 = radians(B[1])
    dlong = long2 - long1
    dlati = lati2 - lati1
    R = 6371
    
    #input given equations 
    a = (sin(dlati / 2) ** 2 + cos(lati1) * cos(lati2) * sin(dlong / 2) ** 2)
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c
    
    print("The distance between coordinates is " + str(distance))

# %%
A = [32,63]
B = [89,41]
calc_dist(A,B)
# Out:
# The distance between coordinates is 4796.058445049785

# %% [markdown]
# ## Part 2: Pandas and NumPy

# %%
import numpy as np
import pandas as pd

# %%
dataset = '/arcgis/home/spatialAnalysisAssignment2/portland_park_trees.csv'

# %%
portland_park_trees = pd.read_csv('/arcgis/home/spatialAnalysisAssignment2/portland_park_trees.csv', sep=",", header=0, encoding="ISO-8859-1")
portland_park_trees.head(10)
# Out:
#    fid  OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  CrownWidth  \
# 0    1       426  2017/05/09    PSME  37.4      Fair       105.0        44.0
# 1    2       427  2017/05/09    PSME  32.5      Fair        94.0        49.0
# 2    3       428  2017/05/09    CRLA   9.7      Fair        23.0        28.0
# 3    4       429  2017/05/09    QURU  10.3      Poor        28.0        38.0
# 4    5       430  2017/05/09    PSME  33.2      Fair       102.0        43.0
# 5    6       431  2017/05/09    PSME  32.1      Fair        95.0        35.0
# 6    7       432  2017/05/09    PSME  28.4      Fair       103.0        40.0
# 7    8       433  2017/05/09    PSME  27.2      Fair       105.0        45.0
# 8    9       434  2017/05/09    PSME  35.2      Fair        97.0        56.0
# 9   10       435  2017/05/09    PSME  32.4      Fair       112.0        35.0
#
#    CrownWid_1 CollectedB  ...        Genus        Common_nam  \
# ...

# %% [markdown]
# ### Question 1: How many trees are of the Quercus or Acer genus?

# %%
A = portland_park_trees['Genus'].value_counts()['Quercus']
B = portland_park_trees['Genus'].value_counts()['Acer']


Quercus_Acer = print(str(A+B) + " trees are of the Quercus or Acer genus")
# Out:
# 5675 trees are of the Quercus or Acer genus

# %% [markdown]
# ### Question 2: How many trees are of the Quercus or Acer genus and have a DBH larger than 50 inches?

# %%
C = len(portland_park_trees[portland_park_trees['DBH'].map(lambda x: x > 50)])

print(str(A+B+C) + " trees are of the Quercus or Acer genus and have a DBH larger than 50 inches")
# Out:
# 6255 trees are of the Quercus or Acer genus and have a DBH larger than 50 inches

# %% [markdown]
# ### Question 3: Which genus has the highest mean DBH of the following genera: Quercus, Acer, or Fraxinus?

# %%
def genus_DBH(genus_type):
    mean = portland_park_trees[(portland_park_trees["Genus"] == genus_type)]['DBH'].mean()
    return mean

genus_types = ['Acer','Quercus','Fraxinus']
mean = 0

for i in range(len(genus_types)):
    if genus_DBH(genus_types[i])>=mean:
        mean = genus_DBH(genus_types[i])
        genus = genus_types[i]
    else:
        i+=1
    
print(genus + " has the highest mean DBH equal to " + str(mean))
# Out:
# Quercus has the highest mean DBH equal to 23.56823839157492

# %% [markdown]
# ### Question 4: How many different species of trees are recorded in the Acer genus?

# %%
Acer_Species = portland_park_trees[(portland_park_trees["Genus"] == "Acer")]['Species'].to_list()
print("There are " + str(len(set(Acer_Species))) + " different species of tree recorded in the Acer genus")
# Out:
# There are 20 different species of tree recorded in the Acer genus

# %% [markdown]
# ### Question 5:
# - Calculate a new column named "pop_M" (population in millions) by transforming the "pop" (population) column.
# - Remove the original "pop" column.
# - Choose/subset a city that starts with the same letter as your first name (for example, "Mexico City" if your first name is Michael).
# - Subset the five biggest (i.e., largest population sizes) cities from the country where your selected city is.
# - Print the result.
# - Make sure you write the scripts in different code cells where you describe the process.

# %%
dataset = '/arcgis/home/spatialAnalysisAssignment2/world_cities.csv'

# %%
world_cities = pd.read_csv('/arcgis/home/spatialAnalysisAssignment2/world_cities.csv', sep=",", header=0, encoding="ISO-8859-1")
world_cities.head(10)
# Out:
#                  city       country    pop    lat    lon  capital
# 0  'Abasan al-Jadidah     Palestine   5629  31.31  34.34        0
# 1  'Abasan al-Kabirah     Palestine  18999  31.32  34.35        0
# 2        'Abdul Hakim      Pakistan  47788  30.55  72.11        0
# 3  'Abdullah-as-Salam        Kuwait  21817  29.36  47.98        0
# 4               'Abud     Palestine   2456  32.03  35.07        0
# 5             'Abwein     Palestine   3434  32.03  35.20        0
# 6            'Adadlay       Somalia   9198   9.77  44.65        0
# 7              'Adale       Somalia   5492   2.75  46.30        0
# 8               'Afak          Iraq  22706  32.07  45.26        0
# 9               'Afif  Saudi Arabia  41731  23.92  42.93        0

# %%
##Calculate a new column named "pop_M" (population in millions), by transforming the "pop" (population) column.##

world_cities['pop_M'] = world_cities['pop'] * 100000
world_cities
# Out:
#                      city       country     pop    lat    lon  capital  \
# 0      'Abasan al-Jadidah     Palestine    5629  31.31  34.34        0
# 1      'Abasan al-Kabirah     Palestine   18999  31.32  34.35        0
# 2            'Abdul Hakim      Pakistan   47788  30.55  72.11        0
# 3      'Abdullah-as-Salam        Kuwait   21817  29.36  47.98        0
# 4                   'Abud     Palestine    2456  32.03  35.07        0
# ...                   ...           ...     ...    ...    ...      ...
# 43640           az-Zubayr          Iraq  124611  30.39  47.71        0
# 43641            az-Zulfi  Saudi Arabia   54070  26.30  44.80        0
# 43642       az-Zuwaytinah         Libya   21984  30.95  20.12        0
# 43643        s-Gravenhage   Netherlands  479525  52.07   4.30        0
# 43644     s-Hertogenbosch   Netherlands  135529  51.68   5.30        0
#
#              pop_M
# 0        562900000
# 1       1899900000
# 2       4778800000
# 3       2181700000
# ...

# %%
##Remove the original "pop" column.##

world_cities = world_cities.drop(['pop'], axis=1)
world_cities
# Out:
#                      city       country    lat    lon  capital        pop_M
# 0      'Abasan al-Jadidah     Palestine  31.31  34.34        0    562900000
# 1      'Abasan al-Kabirah     Palestine  31.32  34.35        0   1899900000
# 2            'Abdul Hakim      Pakistan  30.55  72.11        0   4778800000
# 3      'Abdullah-as-Salam        Kuwait  29.36  47.98        0   2181700000
# 4                   'Abud     Palestine  32.03  35.07        0    245600000
# ...                   ...           ...    ...    ...      ...          ...
# 43640           az-Zubayr          Iraq  30.39  47.71        0  12461100000
# 43641            az-Zulfi  Saudi Arabia  26.30  44.80        0   5407000000
# 43642       az-Zuwaytinah         Libya  30.95  20.12        0   2198400000
# 43643        s-Gravenhage   Netherlands  52.07   4.30        0  47952500000
# 43644     s-Hertogenbosch   Netherlands  51.68   5.30        0  13552900000
#
# [43645 rows x 6 columns]

# %%
##Choose a city that starts with the same English letter as your first name.##
world_cities[world_cities['city'] == "Rennes"]
# Out:
#          city country    lat   lon  capital        pop_M
# 31075  Rennes  France  48.11 -1.68        0  20938000000

# %%
##Subset the five biggest (i.e., largest population sizes) cities from the country where your selected city is. (Do not use the country name string in the code; use an expression which returns it.)
country = world_cities[world_cities['city'] == "Rennes"]['country'].to_list()
subset = world_cities[world_cities['country'] == country[0]].sort_values('pop_M').iloc[995:1000, :]
subset_list = subset['city'].to_list()
print("The five cities in " + country[0] + " with the largest populations are: " + str(subset_list))
# Out:
# The five cities in France with the largest populations are: ['Nice', 'Toulouse', 'Lyon', 'Marseille', 'Paris']

# %% [markdown]
# ## Part 3: Python Data Visualization

# %%
dataset = '/arcgis/home/spatialAnalysisAssignment2/portland_park_trees.csv'

# %%
portland_park_trees = pd.read_csv('/arcgis/home/spatialAnalysisAssignment2/portland_park_trees.csv', sep=",", header=0, encoding="ISO-8859-1")
portland_park_trees.head(10)
# Out:
#    fid  OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  CrownWidth  \
# 0    1       426  2017/05/09    PSME  37.4      Fair       105.0        44.0
# 1    2       427  2017/05/09    PSME  32.5      Fair        94.0        49.0
# 2    3       428  2017/05/09    CRLA   9.7      Fair        23.0        28.0
# 3    4       429  2017/05/09    QURU  10.3      Poor        28.0        38.0
# 4    5       430  2017/05/09    PSME  33.2      Fair       102.0        43.0
# 5    6       431  2017/05/09    PSME  32.1      Fair        95.0        35.0
# 6    7       432  2017/05/09    PSME  28.4      Fair       103.0        40.0
# 7    8       433  2017/05/09    PSME  27.2      Fair       105.0        45.0
# 8    9       434  2017/05/09    PSME  35.2      Fair        97.0        56.0
# 9   10       435  2017/05/09    PSME  32.4      Fair       112.0        35.0
#
#    CrownWid_1 CollectedB  ...        Genus        Common_nam  \
# ...

# %%
pip install numpy
# Out:
# /bin/bash: /opt/conda/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as nd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Graph 1: : Create a scatterplot for just trees in the Ulmus genus with DBH mapped to the x-axisand tree height mapped to the y-axis (Hint: You will need to use the “Genus”, “DBH”, and “TreeHeight” attributes.).

# %%
Ulmus = portland_park_trees[(portland_park_trees['Genus'] == 'Ulmus')][['DBH','TreeHeight']]
Ulmus.plot.scatter(x='DBH', y='TreeHeight').set_title("Tree Height v DBH for Ulmus Genus");

# %% [markdown]
# ### Graph 2: Create a scatterplot for just trees in the Ulmus genus with DBH mapped to the x-axis, tree height mapped to the y-axis, and tree species mapped to hue (Hint: You will need to use the “Genus”, “Genus_spec”, “DBH”, and “TreeHeight” attributes.)

# %%
Ulmus_hue = portland_park_trees[(portland_park_trees['Genus'] == 'Ulmus')][['DBH','TreeHeight','Species']]
sns.scatterplot(data=Ulmus_hue, x='DBH', y='TreeHeight', hue='Species').set_title("Tree Height v DBH by Species for Ulmus Genus");

# %% [markdown]
# ### Graph 3: Create a boxplot of DBH for just the Ulmus genus differentiated by species (or, each species should have its own boxplot).

# %%
Ulmus_DBH_Species = portland_park_trees[(portland_park_trees['Genus'] == 'Ulmus')][['DBH','Species']]
sns.boxplot(data=Ulmus_DBH_Species, x="DBH", y="Species").set_title("Average DBH by Species for Ulmus Genus");

# %% [markdown]
# ### Graph 4: Combine Graphs 1 and 3 into a single figure. Do not plot a legend for any of the graphs

# %%
DBH = Ulmus_hue['DBH']
TreeHeight = Ulmus_hue['TreeHeight']
Species = Ulmus_hue['Species']

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=2, ncols=1)
axes[0].scatter(DBH, TreeHeight)
axes[0].set_ylabel('Tree Height')
axes[0].set_title("Tree Height and Species by DBH for Ulmus Genus")
sns.boxplot(data=Ulmus_DBH_Species, x="DBH", y="Species");

# %% [markdown]
# ## Part 4: Python GeoPandas

# %%
pip install geopandas fiona shapely pyproj rtree contextily folium matplotlib mapclassify
# Out:
# /bin/bash: /opt/conda/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import shapely.geometry
import shapely.wkt
import geopandas as gpd

# %% [markdown]
# ### Task 1: Read the dataset(shapefile) you download as GeoPandas DataFrame

# %%
from arcgis.gis import GIS
gis = GIS("home")

# %%
dataset = '/arcgis/home/spatialAnalysisAssignment2/SSSI_SCOTLAND_SHP_27700.zip'

# %%
SSSI_Scotland = gpd.read_file('/arcgis/home/spatialAnalysisAssignment2/SSSI_SCOTLAND_SHP_27700.zip')
SSSI_Scotland
# Out:
#                                  NAME  PA_CODE   STATUS EUROPEAN_C  \
# 0                  Shielton Peatlands     1426  Current     136090
# 1                      Forsinard Bogs      651  Current     136199
# 2                   Sletill Peatlands     1443  Current     135069
# 3                    West Strathnaver     1611  Current     135128
# 4                      West Halladale     1607  Current     136029
# ...                               ...      ...      ...        ...
# 15872  Bornish and Ormiclate Machairs      246  Current     136154
# 15873  Bornish and Ormiclate Machairs      246  Current     136154
# 15874  Bornish and Ormiclate Machairs      246  Current     136154
# 15875  Bornish and Ormiclate Machairs      246  Current     136154
# 15876                    Bargeny Hill    10496  Current       None
#
#              TYPE  SITE_HA  FEATURE_HA     UPDATED MPA_NETWOR   GEOGRAPHIC  \
# 0      BIOLOGICAL  5631.97     5631.97  2022-03-30          N  TERRESTRIAL
# ...

# %% [markdown]
# ### Task 2: Use the correct code to plot the first 5 and the last 5 sets of records in your selected dataset.

# %%
head = SSSI_Scotland.head(5)
tail = SSSI_Scotland.tail(5)
head_tail = [head, tail]

subset = pd.concat(head_tail)
subset
# Out:
#                                  NAME  PA_CODE   STATUS EUROPEAN_C  \
# 0                  Shielton Peatlands     1426  Current     136090
# 1                      Forsinard Bogs      651  Current     136199
# 2                   Sletill Peatlands     1443  Current     135069
# 3                    West Strathnaver     1611  Current     135128
# 4                      West Halladale     1607  Current     136029
# 15872  Bornish and Ormiclate Machairs      246  Current     136154
# 15873  Bornish and Ormiclate Machairs      246  Current     136154
# 15874  Bornish and Ormiclate Machairs      246  Current     136154
# 15875  Bornish and Ormiclate Machairs      246  Current     136154
# 15876                    Bargeny Hill    10496  Current       None
#
#              TYPE  SITE_HA  FEATURE_HA     UPDATED MPA_NETWOR   GEOGRAPHIC  \
# 0      BIOLOGICAL  5631.97     5631.97  2022-03-30          N  TERRESTRIAL
# 1      BIOLOGICAL  1509.19     1509.19  2015-12-30          N  TERRESTRIAL
# ...

# %%
subset.plot();

# %% [markdown]
# ### Task 3. Create a map where you can explore the selected dataset. Try to plot the map using some categorical attribute. Include a ToolTip.

# %%
SSSI_Scotland.explore(column='TYPE', cmap='RdYlBu', style_kwds={'weight':8, 'opacity':0.8})

# %% [markdown]
# ### Task 4. What is the Coordinate Reference System of the selected dataset?

# %%
SSSI_Scotland.crs
crs = SSSI_Scotland.crs
print("The Coordinate Reference System of the Scotland Sites of Special Scientific Interest dataset is " + str(crs))
# Out:
# The Coordinate Reference System of the Scotland Sites of Special Scientific Interest dataset is epsg:27700

# %% [markdown]
# ### Task 5. How many features does the selected dataset contain?

# %%
features = SSSI_Scotland.shape[0]
print ("The Scotland Sites of Special Scientific Interest dataset has " + str(features) + " features")
# Out:
# The Scotland Sites of Special Scientific Interest dataset has 15877 features

# %% [markdown]
# ### Task 6. Define a sub-setting filter to create a new geopandas dataframe where you filter the selected dataset based on a categorical attribute.

# %%
SSSI_Scotland_Cat = SSSI_Scotland[SSSI_Scotland['TYPE'] == 'BIOLOGICAL']
SSSI_Scotland_Cat
# Out:
#                                  NAME  PA_CODE   STATUS EUROPEAN_C  \
# 0                  Shielton Peatlands     1426  Current     136090
# 1                      Forsinard Bogs      651  Current     136199
# 2                   Sletill Peatlands     1443  Current     135069
# 3                    West Strathnaver     1611  Current     135128
# 4                      West Halladale     1607  Current     136029
# ...                               ...      ...      ...        ...
# 15872  Bornish and Ormiclate Machairs      246  Current     136154
# 15873  Bornish and Ormiclate Machairs      246  Current     136154
# 15874  Bornish and Ormiclate Machairs      246  Current     136154
# 15875  Bornish and Ormiclate Machairs      246  Current     136154
# 15876                    Bargeny Hill    10496  Current       None
#
#              TYPE  SITE_HA  FEATURE_HA     UPDATED MPA_NETWOR   GEOGRAPHIC  \
# 0      BIOLOGICAL  5631.97     5631.97  2022-03-30          N  TERRESTRIAL
# ...

# %% [markdown]
# ### Task 7. Define a sub-setting filter to create a new geopandas dataframe where you filter theselected dataset based on a numerical attribute.

# %%
sel2 = SSSI_Scotland["Shape_Area"] > 1.000000e+07
SSSI_Scotland_Num = SSSI_Scotland[sel2]
SSSI_Scotland_Num
##Scotish Sites of Special Scientific Interest with areas greater than 1.000000e+07
# Out:
#                       NAME  PA_CODE   STATUS EUROPEAN_C        TYPE   SITE_HA  \
# 0       Shielton Peatlands     1426  Current     136090  BIOLOGICAL   5631.97
# 1           Forsinard Bogs      651  Current     136199  BIOLOGICAL   1509.19
# 2        Sletill Peatlands     1443  Current     135069  BIOLOGICAL   2985.46
# 3         West Strathnaver     1611  Current     135128  BIOLOGICAL   2735.17
# 4           West Halladale     1607  Current     136029  BIOLOGICAL   8658.85
# ...                    ...      ...      ...        ...         ...       ...
# 15711  Cairnsmore of Fleet      290  Current     135669  BIOLOGICAL   3825.09
# 15712     Muirkirk Uplands     8166  Current     174685       MIXED  19154.00
# 15713     Muirkirk Uplands     8166  Current     174685       MIXED  19154.00
# 15714     Muirkirk Uplands     8166  Current     174685       MIXED  19154.00
# 15821            Ben Loyal      187  Current     136021       MIXED   4339.27
#
# ...

# %% [markdown]
# ### Task 8. Plot the new/filtered geopandas dataframe using one of the attributes to create a choropleth map

# %%
SSSI_Scotland_Num.plot(column="Shape_Area", legend=True,
    legend_kwds={"label": "Shape Area"},);

# %% [markdown]
# ## Part 5: Python Rasterrio

# %%
pip install earthpy rasterio
# Out:
# /bin/bash: /opt/conda/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import rasterio
from rasterio.plot import show

import numpy as np
import shapely
import geopandas as gpd

import glob

# %%
dataset = '/arcgis/home/spatialAnalysisAssignment2/elev.tif'

# %% [markdown]
# ### Task 1. Read the file as a rasterio dataset

# %%
elv = rasterio.open('/arcgis/home/spatialAnalysisAssignment2/elev.tif')
elv
# Out:
# <open DatasetReader name='/arcgis/home/spatialAnalysisAssignment2/elev.tif' mode='r'>

# %% [markdown]
# ### Task 2: What is the CRS of the dataset?

# %%
crs = elv.crs
print("The CRS of the dataset is " + str(crs))
# Out:
# The CRS of the dataset is EPSG:32617

# %% [markdown]
# ### Task 3: Describe the raster dataset regarding the raster extent (bounds), the reference system, and how many bands are in this dataset.

# %%
elv.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'int16',
#  'nodata': -32768.0,
#  'width': 6303,
#  'height': 5897,
#  'count': 1,
#  'crs': CRS.from_epsg(32617),
#  'transform': Affine(30.0, 0.0, 479753.39945587853,
#         0.0, -30.0, 4347733.203759138)}

# %%
bounds = elv.bounds
reference_system = elv.crs
bands = elv.count

print("This raster dataset has an extent of: " + str(bounds) + ". It uses a " + str(reference_system) + " reference system and it has a band count of " + str(bands))
# Out:
# This raster dataset has an extent of: BoundingBox(left=479753.39945587853, bottom=4170823.2037591375, right=668843.3994558785, top=4347733.203759138). It uses a EPSG:32617 reference system and it has a band count of 1

# %% [markdown]
# ### Task 4: Create a plot/map of the raster dataset.

# %%
show(elv);

# %% [markdown]
# ### Task 5: Create Histograms from the raster.

# %%
from rasterio.plot import show_hist
show_hist(
    elv, bins=50, lw=0.0, stacked=False, alpha=0.3,
    histtype='stepfilled', title="Histogram")
